# %%
import pandas as pd
from pytrends.request import TrendReq
# Initialize pytrends request
pytrends = TrendReq(hl='es-MX', tz=360)

# %%
# List of keywords we want to analyze
keywords_list = ["ia", "search engine optimization", "analytics", "web development", "technology" ]

# Initialize an empty DataFrame to store the results
all_rising_topics_df = pd.DataFrame()

# Iterate over each keyword in the list
for keyword in keywords_list:
    # Build payload for the keyword
    pytrends.build_payload([keyword], cat=0, timeframe="today 3-m", geo="MX")
    
    # Get related topics for the keyword
    related_topics = pytrends.related_topics()
    
    # Extract rising topics for the keyword, if available
    if related_topics and keyword in related_topics and 'rising' in related_topics[keyword]:
        rising_df = related_topics[keyword]['rising'].copy()  # Make a copy of the rising topics DataFrame
        # Normalize the DataFrame by dropping unnecessary columns, if desired
        rising_df = rising_df.drop(columns=['link', 'topic_mid'])
        # Add a 'keyword' column to indicate which keyword the topics belong to
        rising_df['keyword'] = keyword
        # Append the rising topics DataFrame to the main all_rising_topics_df
        all_rising_topics_df = pd.concat([all_rising_topics_df, rising_df], ignore_index=True)

# Display the final concatenated DataFrame of rising topics for all keywords
print(all_rising_topics_df)
# Out:
#       value formattedValue                                        topic_title  \
# 0     75650        Aumento                        Generador de imágenes de IA
# 1     18850        Aumento                                    Marcela Mistral
# 2     15000        Aumento                       Leonardo Interactive Pty Ltd
# 3       200         +200 %                                               NSFW
# 4        70          +70 %                                      Renderización
# 5        60          +60 %                                            Censura
# 6        80          +80 %                                          Marketing
# 7     94650        Aumento                                          Propiedad
# 8     59850        Aumento                          Cualificación profesional
# 9     48300        Aumento                                          Hootsuite
# 10    47800        Aumento                                     Implementación
# 11    45900        Aumento                                  punto de contacto
# 12    45250        Aumento                                     Salesforce.com
# 13    33800        Aumento  Honeywell XNX XNX-RMAV-NNIV1 Universal Transmi...
# 14    32000        Aumento                                          Algoritmo
# 15    29750        Aumento                                            HubSpot
# 16    27900        Aumento                                          Auditoría
# 17    26850        Aumento                                           Detector
# 18    22100        Aumento                               Campaña publicitaria
# 19    17000        Aumento                     Indicador clave de rendimiento
# 20    16750        Aumento                                  Revista académica
# 21     1100       +1,100 %                                    Radiotransmisor
# 22      350         +350 %                                            Insight
# 23      300         +300 %                                       Análisis web
# 24      110         +110 %                                               XNXX
# 25      110         +110 %                                Honeywell Analytics
# 26      100         +100 %                                Honeywell Analytics
# 27  1319400        Aumento             Proceso para el desarrollo de software
# 28   744800        Aumento                                               Dato
# 29   276250        Aumento                                            Flutter
# 30       60          +60 %                                         Asignatura
# 31       60          +60 %                                           Proyecto
# 32       60          +60 %                                           Software
# 33       60          +60 %                                            Archivo
# 34    51350        Aumento                                  Micron Technology
# 35    25900        Aumento                                           Adopción
# 36    24850        Aumento                                          Cognizant
# 37     9500        Aumento                                 Smart Technologies
# 38      600         +600 %                                           Cerámica
# 39      550         +550 %                                           Palworld
# 40      500         +500 %                                      Globalización
# 41      450         +450 %                               Inversor de potencia
# 42      250         +250 %                                             Cantón
# 43      200         +200 %                                          Cognizant
# 44      200         +200 %                                         Smart Tech
# 45      180         +180 %                               Alisadora de cabello
# 46      170         +170 %                                  Factor de impacto
# 47      140         +140 %                                          Hong Kong
# 48      130         +130 %                   KTH Real Instituto de Tecnología
# 49      130         +130 %                                              Intel
# 50      100         +100 %                                             Micron
# 51       50          +50 %                                   Dahua Technology
# 52       50          +50 %                     Intel Rapid Storage Technology
#
#                                            topic_type  \
# 0                                          Aplicación
# 1   Presentadora de televisión ‧ Esposa de Poncho ...
# 2                                             Empresa
# 3                                                Tema
# 4                               Categoría de software
# 5                                                Tema
# 6                                                Tema
# 7                                                Tema
# 8                                Título universitario
# 9                                                Tema
# 10                                               Tema
# 11                                               Tema
# 12                                            Empresa
# 13                                    Detector de gas
# 14                                               Tema
# 15                                Empresa de software
# 16                                               Tema
# 17                                               Tema
# 18                                               Tema
# 19                                               Tema
# 20                                               Tema
# 21                                               Tema
# 22                                         Psicología
# 23                                               Tema
# 24                                          Sitio web
# 25                                               Tema
# 26                                            Empresa
# 27                                               Tema
# 28                                               Tema
# 29                                           Software
# 30                                               Tema
# 31                                               Tema
# 32                                               Tema
# 33                                        Informática
# 34                                            Empresa
# 35                                               Tema
# 36                                            Empresa
# 37                                 Cadena de software
# 38                                               Tema
# 39                                         Videojuego
# 40                                               Tema
# 41                                               Tema
# 42                                    Ciudad en China
# 43                                               Tema
# 44                                               Tema
# 45                                               Tema
# 46                                               Tema
# 47                     Región administrativa especial
# 48                   Universidad en Estocolmo, Suecia
# 49                                               Tema
# 50                                               Tema
# 51                         Empresa de capital abierto
# 52                                               Tema
#
#                        keyword
# 0                           ia
# 1                           ia
# 2                           ia
# 3                           ia
# 4                           ia
# 5                           ia
# 6   search engine optimization
# 7                    analytics
# 8                    analytics
# 9                    analytics
# 10                   analytics
# 11                   analytics
# 12                   analytics
# 13                   analytics
# 14                   analytics
# 15                   analytics
# 16                   analytics
# 17                   analytics
# 18                   analytics
# 19                   analytics
# 20                   analytics
# 21                   analytics
# 22                   analytics
# 23                   analytics
# 24                   analytics
# 25                   analytics
# 26                   analytics
# 27             web development
# 28             web development
# 29             web development
# 30             web development
# 31             web development
# 32             web development
# 33             web development
# 34                  technology
# 35                  technology
# 36                  technology
# 37                  technology
# 38                  technology
# 39                  technology
# 40                  technology
# 41                  technology
# 42                  technology
# 43                  technology
# 44                  technology
# 45                  technology
# 46                  technology
# 47                  technology
# 48                  technology
# 49                  technology
# 50                  technology
# 51                  technology
# 52                  technology

# %%
all_rising_topics_df.to_csv('rising_topics.csv', index=False, encoding='utf-8-sig')

# %%
# List of keywords you want to analyze
keywords_list = ["doctorado", "maestría", "diplomatura", "licenciatura", "cursos online"]

# Diccionario para almacenar los DataFrames de resultado
rising_topics_dict = {}

# Bucle para cada palabra clave en la lista
for keyword in keywords_list:
    # Creamos la consulta con la palabra clave actual
    pytrends.build_payload([keyword], cat=0, timeframe="today 3-m", geo="MX")
    
    # Obtenemos los tópicos relacionados con la palabra clave
    related_topics = pytrends.related_topics()
    
    # Obtenemos el valor de la clave de palabra en el diccionario de tópicos relacionados
    # y extraemos los tópicos con volumen creciente si existen
    keyword_related_topics = related_topics.get(keyword, {})
    rising_topics = keyword_related_topics.get('rising', {})
    
    # Almacenamos los resultados en nuestro diccionario con clave de palabra
    if rising_topics is not None:
        rising_topics_dict[keyword] = rising_topics

# Impresión de los datos relacionados 
print(rising_topics_dict["doctorado"])
# Out:
#     value formattedValue                                               link  \
# 0   83050        Aumento  /trends/explore?q=/g/122blxsd&date=today+3-m&g...
# 1   74950        Aumento  /trends/explore?q=/g/11bc5q30fv&date=today+3-m...
# 2   56650        Aumento  /trends/explore?q=/g/1tfb6xtm&date=today+3-m&g...
# 3   56500        Aumento   /trends/explore?q=/m/05wd8&date=today+3-m&geo=MX
# 4   49750        Aumento  /trends/explore?q=/g/1224nm_8&date=today+3-m&g...
# 5   46850        Aumento   /trends/explore?q=/m/04pnx&date=today+3-m&geo=MX
# 6   45350        Aumento  /trends/explore?q=/g/11c1wj70lc&date=today+3-m...
# 7   35350        Aumento  /trends/explore?q=/m/04f0qp3&date=today+3-m&ge...
# 8   34150        Aumento  /trends/explore?q=/m/03clf9c&date=today+3-m&ge...
# 9   31300        Aumento  /trends/explore?q=/m/05js3c&date=today+3-m&geo=MX
# 10  22850        Aumento  /trends/explore?q=/m/027nx8&date=today+3-m&geo=MX
# 11    400         +400 %  /trends/explore?q=/g/1232c2p2&date=today+3-m&g...
# 12    350         +350 %  /trends/explore?q=/m/02gzlx&date=today+3-m&geo=MX
# 13    300         +300 %  /trends/explore?q=/g/11h1tkkjn&date=today+3-m&...
# 14    300         +300 %  /trends/explore?q=/m/07hnpj&date=today+3-m&geo=MX
# 15    300         +300 %   /trends/explore?q=/m/05d5r&date=today+3-m&geo=MX
# 16    300         +300 %  /trends/explore?q=/m/03nfmq&date=today+3-m&geo=MX
# 17    250         +250 %   /trends/explore?q=/m/0dczl&date=today+3-m&geo=MX
# 18    250         +250 %  /trends/explore?q=/m/02vkc4z&date=today+3-m&ge...
# 19    250         +250 %  /trends/explore?q=/g/11shnm_xht&date=today+3-m...
# 20    250         +250 %  /trends/explore?q=/g/11bbrnpfjj&date=today+3-m...
# 21     40          +40 %  /trends/explore?q=/m/0dbs2n&date=today+3-m&geo=MX
# 22     40          +40 %   /trends/explore?q=/m/06cs1&date=today+3-m&geo=MX
# 23     40          +40 %   /trends/explore?q=/m/05qfh&date=today+3-m&geo=MX
#
#         topic_mid                                        topic_title  \
# 0     /g/122blxsd      Reconocimiento de Validez Oficial de Estudios
# 1   /g/11bc5q30fv                          Investigación posdoctoral
# 2     /g/1tfb6xtm                               Centro Universitario
# 3        /m/05wd8                                      Psicoanálisis
# 4     /g/1224nm_8                                   Ingeniería civil
# 5        /m/04pnx                                      Latinoamérica
# 6   /g/11c1wj70lc             Universidad Autónoma de Aguascalientes
# 7      /m/04f0qp3                Facultad de Filosofía y Letras UNAM
# 8      /m/03clf9c             Universidad Juárez Autónoma de Tabasco
# 9       /m/05js3c                                Comprensión lectora
# 10      /m/027nx8                            Investigación educativa
# 11    /g/1232c2p2                        Administración hospitalaria
# 12      /m/02gzlx                                 Psicología clínica
# 13   /g/11h1tkkjn        Universidad Abierta y a Distancia de México
# 14      /m/07hnpj                     Universidad de Sonora - UNISON
# 15       /m/05d5r                                     Nanotecnología
# 16      /m/03nfmq                                       Arquitectura
# 17       /m/0dczl                            Las ciencias biomédicas
# 18     /m/02vkc4z                             Especialidad medicinal
# 19  /g/11shnm_xht                                  gestión educativa
# 20  /g/11bbrnpfjj                    Universidad Autónoma de Sinaloa
# 21      /m/0dbs2n  Consejo Nacional de Humanidades, Ciencias y Te...
# 22       /m/06cs1                                      Investigación
# 23       /m/05qfh                                         Psicología
#
#                                           topic_type
# 0                                               Tema
# 1                                   Título académico
# 2                                               Tema
# 3                                               Tema
# 4                                               Tema
# 5                                             Región
# 6                                               Tema
# 7               Departamento universitario en México
# 8        Universidad pública en Villahermosa, México
# 9                                               Tema
# 10                                              Tema
# 11                                              Tema
# 12                                              Tema
# 13  Institución de educación universitaria en México
# 14                 Universidad en Hermosillo, México
# 15                                              Tema
# 16                                  Campo de estudio
# 17                                              Tema
# 18                                              Tema
# 19                                  Campo de estudio
# 20                                              Tema
# 21                               Agencia de gobierno
# 22                              Tipo de organización
# 23                                  Campo de estudio
